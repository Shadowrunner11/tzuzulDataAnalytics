# %%
import matplotlib.pyplot as plt

plt.plot([ 1 ,4, 9, 16, 25, 36, 49],[1,2,3,4,5,6,7], 'ro')

# %%
import math
import numpy
tiempo = numpy.arange(0, 5.5, 0.1)
y = numpy.sin(math.pi*tiempo)
y2 = numpy.cos(math.pi*tiempo)

plt.plot(tiempo, y, 'r--',tiempo, y2, 'b')
